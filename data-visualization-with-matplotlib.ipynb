# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#exemple 1 
x = [2,3,4,5] 
y = [4,8,12,16] 
plt.plot(x, y, "o") 
plt.show()

# %%
#exemple 2 
 
x1 = [2,3,4,5] 
y1 = [4,8,12,16] 
x2 = [5,6,7,8] 
y2 = [5,10,15,10] 
plt.plot(x1, y1, "o") 
plt.plot(x2, y2, "x") 
 
plt.show()

# %%
#Exemple 4 
x1 = [2,3,4,5] 
y1 = [4,8,12,16] 
x2 = [5,6,7,8] 
y2 = [5,10,15,10] 
x3 = [2,5,8,11] 
y3 = [2,6,9,17] 
plt.plot(x1, y1, "ro") 
plt.plot(x2, y2, "gx") 
plt.plot(x3, y3) 
plt.show()

# %%
x = np.arange(0, 50) 
y=np.arange(1,200,4) 
plt.plot(x, y)

# %%
def f(x): 
    return x*x 
x = np.arange(0, 50) 
y=f(x) 
plt.plot(x, y) 
 
#afficher le contenu de y

# %%
dataset=pd.read_csv("diabetes.csv") 
zero_not_accepted=['Glucose','BloodPressure','SkinThickness','BMI','Insulin'] 
                   
for column in zero_not_accepted:
    dataset[column]=dataset[column].replace(0,np.NaN) 
    mean = int(dataset[column].mean(skipna=True)) 
    
dataset[column]=dataset[column].replace(np.NaN,mean) 
x=dataset.loc[:,'Age'] 
y=dataset.loc[:,'Glucose']

plt.plot(x, y,'.')

# %%
dataset=pd.read_csv("diabetes.csv") 
zero_not_accepted=['Glucose','BloodPressure','SkinThickness','BMI','Insulin'] 

for column in zero_not_accepted: 
    dataset[column]=dataset[column].replace(0,np.NaN) 
    mean=int(dataset[column].mean(skipna=True))    
    dataset[column]=dataset[column].replace(np.NaN,mean) 

C1=dataset.loc[dataset['Outcome']==1,:] 
C0=dataset.loc[dataset['Outcome']==0,:] 

x1=C1.loc[:,'Age'] 
y1=C1.loc[:,'Glucose'] 
x2=C0.loc[:,'Age'] 
y2=C0.loc[:,'Glucose'] 

plt.plot(x1, y1,'g.') 
plt.plot(x2, y2,'rx')
